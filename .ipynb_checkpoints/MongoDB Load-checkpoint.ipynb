# %%
import pyspark
from pyspark.sql import SparkSession

import numpy as np
import pymongo 

import datetime, time
from datetime import datetime

import os

# %%
client = pymongo.MongoClient()

db = client['fleet']

fleet1 = db['CarTrack']

# %%
spark = SparkSession.builder.appName("App").getOrCreate()
data_dir = 'D:\\Telematics\\Car Track\\Data'
os.listdir(data_dir)
#file = os.path.join(data_dir, os.listdir(data_dir)[3])
#df = spark.read.csv(file, inferSchema=True, header=True)
# Test one trip
#df = spark.read.csv(os.path.join(data_dir, os.listdir(data_dir)[0]), inferSchema=True, header=True, sep=";")
#df_clean = df.drop("Events", "Vision Events", "Geofences", "Location", "Odometer", "Linear G", "Lateral G", "Road Speed").dropDuplicates().sort("Date").withColumnRenamed("Speed", "velocity")
# Out:
# ['CA641377-2022-08-01-23_21_41-2022-08-01-23_47_00.csv',
#  'KF44LNGP joined.csv',
#  'KF44LNGP-2022-07-01-00_00_00-2022-08-08-23_59_59.xlsx',
#  'KK65XRGP joined.csv',
#  'KK65XRGP-2022-07-01-00_00_00-2022-07-22-23_59_59.xlsx',
#  'KN34FKGP joined.csv',
#  'KN34FKGP-2022-08-01-00_00_00-2022-08-18-23_59_59.xlsx',
#  'KR01ZBGP joined.csv',
#  'KR01ZBGP-2022-07-05-00_00_00-2022-07-27-23_59_59.xlsx']

# %%
file = os.path.join(data_dir, os.listdir(data_dir)[5])
df = spark.read.csv(file, inferSchema=True, header=True)
df_clean = df.drop("Events", "Vision Events", "Geofences", "Location", "Odometer", "Linear G", "Lateral G", "Road Speed").dropDuplicates().sort("Date").withColumnRenamed("Speed", "velocity")

# %%
df_clean.show()
# Out:
# +-------------------+----------+---------+--------+
# |               Date|  Latitude|Longitude|velocity|
# +-------------------+----------+---------+--------+
# |2022-08-01 06:30:35|-25.979361|28.223217|       0|
# |2022-08-01 06:30:36|-25.979361|28.223217|       0|
# |2022-08-01 06:30:45|-25.979361|28.223217|       0|
# |2022-08-01 06:30:55|-25.979361|28.223217|       0|
# |2022-08-01 06:31:05|-25.979361|28.223217|       0|
# |2022-08-01 06:31:15|-25.979361|28.223217|       0|
# |2022-08-01 06:31:25|-25.979361|28.223217|       0|
# |2022-08-01 06:31:35|-25.979361|28.223217|       0|
# |2022-08-01 06:31:45|-25.979361|28.223217|       0|
# |2022-08-01 06:31:55|-25.979361|28.223217|       0|
# |2022-08-01 06:32:05|-25.979361|28.223217|       0|
# |2022-08-01 06:32:15|-25.979361|28.223217|       0|
# |2022-08-01 06:32:20|  -25.9793|28.222998|       0|
# |2022-08-01 06:32:29|  -25.9793|28.222998|       0|
# |2022-08-01 06:32:39|  -25.9793|28.222998|       0|
# |2022-08-01 06:32:49|  -25.9793|28.222998|       0|
# |2022-08-01 06:32:50|-25.979292|28.223063|       5|
# |2022-08-01 06:32:52|-25.979256|28.223066|       8|
# |2022-08-01 06:33:02|-25.978975| 28.22311|      17|
# |2022-08-01 06:33:12|-25.978584|28.223181|      14|
# +-------------------+----------+---------+--------+
# only showing top 20 rows

# %%
def getISODate(df):
    return np.array([x.Date.isoformat() + "Z" for x in df.select("Date").collect()])

# %%
def getDate(df):
    return [x.Date for x in df.select("Date").collect()]

# %%
def getParameter(df, param):
    match param:
        case "Latitude":
            return np.array([x.Latitude for x in df.select("Latitude").collect()])
        case "Longitude":
            return np.array([x.Longitude for x in df.select("Longitude").collect()])
        case "velocity":
            return np.array([x.velocity for x in df.select("velocity").collect()])
        case _:
            return None

# %%
lat = getParameter(df_clean, "Latitude")
lng = getParameter(df_clean, "Longitude")
velocity = getParameter(df_clean, "velocity")

# %%
date = getDate(df_clean)

# %%
class tag:
    def __init__(self, numPlate):
        self.numPlate = numPlate
    def getLatTag(self):
        return self.numPlate + "_lat"
    def getVelocityTag(self):
        return self.numPlate + "_V"
    def getLngTag(self):
        return self.numPlate + "_lng"
    def getNumPlate(self):
        return self.numPlate

# %%
car = tag("KN34FKGP")
car.getVelocityTag()
# Out:
# 'KN34FKGP_V'

# %%
tag_lat = "KK65XRGP_lat"
tag_lng = "KK65XRGP_lng"
tag_vel = "KK65XRGP_V"

# %%
def latCollection(date, lat, tag):
    col = []
    for i in range(len(date)):
        temp = {
            "tag": tag, 
            #"date": date[i],
            "timestamp": date[i],
            "latitude": lat[i]
        }
        
        col.append(temp)
    return col

# %%
def lngCollection(date, lng, tag):
    col = []
    for i in range(len(date)):
        temp = {
            "tag": tag, 
            #"date": date[i],
            "timestamp": date[i],
            "longitude": lng[i]
        }
        
        col.append(temp)
    return col

# %%
def velCollection(date, velocity, tag):
    col = []
    for i in range(len(date)):
        temp = {
            "tag": tag, 
            #"date": date[i],
            "timestamp": date[i],           
            "velocity": int(velocity[i])
        }
        
        col.append(temp)
    return col

# %%
insertLat = latCollection(date, lat, car.getLatTag())
insertLng = lngCollection(date, lng, car.getLngTag())
insertVel = velCollection(date, velocity, car.getVelocityTag())

# %%
fleet1.insert_one({
    "tag":"YBC193GP_V",
    "timestamp": datetime.now(),
    "velocity": 45
})

# %%
temp = insertLat[0]
temp

# %%
fleet1.insert_many(insertLat)

# %%
for x in fleet1.find():
    print(x)

# %%
fleet1.insert_many(insertLng)

# %%
fleet1.insert_many(insertVel)

# %%
for x in fleet1.find({"tag": "KK65XRGP_V"}):
    print(x)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 48, 24), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff730'), 'velocity': 43}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 48, 37), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff731'), 'velocity': 53}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 48, 47), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff732'), 'velocity': 77}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 48, 56), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff733'), 'velocity': 92}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 49, 8), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff734'), 'velocity': 81}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 49, 18), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff735'), 'velocity': 95}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 49, 38), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff736'), 'velocity': 100}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 49, 48), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff737'), 'velocity': 103}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 49, 58), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff738'), 'velocity': 103}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 50, 8), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff739'), 'velocity': 104}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 50, 46), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff73a'), 'velocity': 0}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 50, 55), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff73b'), 'velocity': 109}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 51, 15), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff73c'), 'velocity': 113}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 52, 20), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff73d'), 'velocity': 103}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 52, 30), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2ff73e'), 'velocity': 101}
# {'timestamp': datetime.datetime(2022, 7, 20, 10, 52, 40), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec2
 23), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec30079e'), 'velocity': 115}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 27, 33), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec30079f'), 'velocity': 117}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 28, 9), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a0'), 'velocity': 118}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 28, 19), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a1'), 'velocity': 116}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 28, 29), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a2'), 'velocity': 119}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 29, 15), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a3'), 'velocity': 126}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 29, 21), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a4'), 'velocity': 133}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 29, 28), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a5'), 'velocity': 126}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 29, 47), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a6'), 'velocity': 132}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 30, 58), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a7'), 'velocity': 109}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 31, 8), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a8'), 'velocity': 109}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 31, 43), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007a9'), 'velocity': 115}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 31, 53), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007aa'), 'velocity': 114}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 32, 4), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007ab'), 'velocity': 118}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 33, 7), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007ac'), 'velocity': 94}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 33, 22), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007ad'), 'velocity': 83}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 33, 51), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007ae'), 'velocity': 78}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 34, 4), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007af'), 'velocity': 71}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 34, 14), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b0'), 'velocity': 64}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 34, 24), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b1'), 'velocity': 26}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 35, 8), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b2'), 'velocity': 11}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 35, 18), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b3'), 'velocity': 56}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 35, 43), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b4'), 'velocity': 87}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 35, 53), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b5'), 'velocity': 87}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 36, 3), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b6'), 'velocity': 22}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 36, 13), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b7'), 'velocity': 22}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 36, 23), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b8'), 'velocity': 40}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 36, 33), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007b9'), 'velocity': 25}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 36, 45), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007ba'), 'velocity': 24}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 36, 55), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007bb'), 'velocity': 27}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 37, 7), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007bc'), 'velocity': 9}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 37, 51), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007bd'), 'velocity': 20}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 38, 6), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007be'), 'velocity': 19}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 38, 27), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007bf'), 'velocity': 14}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 38, 37), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c0'), 'velocity': 8}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 39, 26), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c1'), 'velocity': 14}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 39, 36), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c2'), 'velocity': 15}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 39, 46), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c3'), 'velocity': 12}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 40, 18), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c4'), 'velocity': 10}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 40, 28), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c5'), 'velocity': 21}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 40, 41), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c6'), 'velocity': 10}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 40, 52), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c7'), 'velocity': 17}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 41, 2), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c8'), 'velocity': 10}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 41, 12), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007c9'), 'velocity': 12}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 41, 22), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007ca'), 'velocity': 19}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 41, 30), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007cb'), 'velocity': 0}
# {'timestamp': datetime.datetime(2022, 7, 22, 18, 43, 48), 'tag': 'KK65XRGP_V', '_id': ObjectId('62fe7ae1f29ed8c4ec3007cc'), 'velocity': 0}

# %%
print(len([x for x in fleet1.find()]))
# Out:
# 87386

# %%
df_clean.count()*len(df_clean.select("Latitude","Longitude", "velocity").columns)
# Out:
# 86976

# %%
fleet1.find({"tag": "KK65XRGP_lat"}).
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 fleet1.find({"tag": "KK65XRGP_lat"}).pretty()
#
# AttributeError: 'Cursor' object has no attribute 'pretty'

# %%
fleet1.explain("executionStats")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 fleet1.explain("executionStats")
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pymongo\collection.py:3200, in Collection.__call__(self, *args, **kwargs)
#    3193 if "." not in self.__name:
#    3194     raise TypeError(
#    3195         "'Collection' object is not callable. If you "
#    3196         "meant to call the '%s' method on a 'Database' "
#    3197         "object it is failing because no such method "
#    3198         "exists." % self.__name
#    3199     )
# -> 3200 raise TypeError(
#    3201     "'Collection' object is not callable. If you meant to "
#    3202     "call the '%s' method on a 'Collection' object it is "
#    3203     "failing because no such method exists." % self.__name.split(".")[-1]
#    3204 )
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'explain' method on a 'Collection' object it is failing because no such method exists.
