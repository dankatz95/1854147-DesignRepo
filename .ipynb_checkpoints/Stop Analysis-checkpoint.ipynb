# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

import datetime, time
from datetime import datetime
from pyspark.sql import Row

import numpy as np
import math

import os
import pymongo


from functions.Plots import *
from functions.PowerCalculation import *
from functions.Resample import *
from functions.StopPointDetection import *
from functions.Elevation import getElevation, getAngles
from functions.ImportVehicle import *
import pandas as pd
import plotly.express as px

from sklearn.cluster import DBSCAN
from collections import Counter
from sklearn.preprocessing import StandardScaler

# %%
spark = SparkSession.builder.appName("App").getOrCreate()

# %%
client = pymongo.MongoClient("mongodb+srv://dankatz95:1234@energycluster.15yrxyi.mongodb.net/?retryWrites=true&w=majority")

db = client['Fleet']
processed= db['Processed']
Trips = db['Trips1']
Cars = db['Cars']
Stops = db['Stops1']
Days = db['Days']

# %%
def getTimeVal(x):
    res = x.split(":")
    x = int(res[1])+int(res[2])/60
    y = x/60
    z = int(res[0]) + y
    return z

def min2(x,y):
    if x < y:
        return x
    else:
        return y

# %%
carCollection = Cars.find()
car_details = []
for car in carCollection:
    car_details.append(car)
    
car_details
# Out:
# [{'_id': ObjectId('6313e73563210332f11d3604'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Area': 2.5899999141693115,
#   'Mass': 1285,
#   'DragCoefficient': 0.28999999165534973,
#   'Mu': 0.019999999552965164,
#   'Make': 'Toyota',
#   'Model': 'Corolla',
#   'Year': 2022},
#  {'_id': ObjectId('6313e73663210332f11d3605'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Area': 2.5899999141693115,
#   'Mass': 1285,
#   'DragCoefficient': 0.28999999165534973,
#   'Mu': 0.019999999552965164,
#   'Make': 'Toyota',
#   'Model': 'Corolla',
#   'Year': 2021},
#  {'_id': ObjectId('6313e73663210332f11d3606'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Area': 2.5899999141693115,
#   'Mass': 1285,
#   'DragCoefficient': 0.28999999165534973,
#   'Mu': 0.019999999552965164,
#   'Make': 'Toyota',
#   'Model': 'Corolla',
#   'Year': 2021},
#  {'_id': ObjectId('6313e73663210332f11d3607'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Area': 2.5399999618530273,
#   'Mass': 1254,
#   'DragCoefficient': 0.2800000011920929,
#   'Mu': 0.019999999552965164,
#   'Make': 'Nissan',
#   'Model': 'Almera',
#   'Year': 2022},
#  {'_id': ObjectId('6313e73663210332f11d3608'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Area': 2.5399999618530273,
#   'Mass': 1254,
#   'DragCoefficient': 0.2800000011920929,
#   'Mu': 0.019999999552965164,
#   'Make': 'Nissan',
#   'Model': 'Almera',
#   'Year': 2022},
#  {'_id': ObjectId('6313e73663210332f11d3609'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Area': 2.5399999618530273,
#   'Mass': 1254,
#   'DragCoefficient': 0.2800000011920929,
#   'Mu': 0.019999999552965164,
#   'Make': 'Nissan',
#   'Model': 'Almera',
#   'Year': 2022}]

# %%
trips = Trips.find()

trip_details = []
for trip in trips:
    trip_details.append(trip)

# %%
trip_details

# %%
dayCollection = Days.find()
daysInfo = []
for d in dayCollection:
    daysInfo.append(d)
daysInfo
# Out:
# [{'_id': ObjectId('6318488d6861b716cea11b55'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 1, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 335.6023741886524,
#   'DrivingTime': 22480.0,
#   'TotalEnergy': 74.51778544600052,
#   'TotalStops': 7,
#   'TotalStopTime': 32490.0},
#  {'_id': ObjectId('631848926861b716cea11b56'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 2, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 314.6264532183681,
#   'DrivingTime': 21110.0,
#   'TotalEnergy': 74.4465614137473,
#   'TotalStops': 7,
#   'TotalStopTime': 58620.0},
#  {'_id': ObjectId('631848966861b716cea11b57'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 3, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 448.435236226725,
#   'DrivingTime': 30460.0,
#   'TotalEnergy': 99.03180212782699,
#   'TotalStops': 8,
#   'TotalStopTime': 14460.0},
#  {'_id': ObjectId('631848996861b716cea11b58'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 4, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 354.81538070840446,
#   'DrivingTime': 26120.0,
#   'TotalEnergy': 83.52762025100982,
#   'TotalStops': 8,
#   'TotalStopTime': 54220.0},
#  {'_id': ObjectId('6318489d6861b716cea11b59'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 5, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 275.2303498120363,
#   'DrivingTime': 23360.0,
#   'TotalEnergy': 69.25580810682322,
#   'TotalStops': 9,
#   'TotalStopTime': 61520.0},
#  {'_id': ObjectId('631848a16861b716cea11b5a'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 6, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 282.35395143916026,
#   'DrivingTime': 21710.0,
#   'TotalEnergy': 63.99786553772856,
#   'TotalStops': 4,
#   'TotalStopTime': 52870.0},
#  {'_id': ObjectId('631848a56861b716cea11b5b'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 7, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 335.0841052741151,
#   'DrivingTime': 27590.0,
#   'TotalEnergy': 81.13029672119515,
#   'TotalStops': 12,
#   'TotalStopTime': 53710.0},
#  {'_id': ObjectId('631848a96861b716cea11b5c'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 8, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 248.39355283745977,
#   'DrivingTime': 21150.0,
#   'TotalEnergy': 59.646748558617595,
#   'TotalStops': 6,
#   'TotalStopTime': 52410.0},
#  {'_id': ObjectId('631848ad6861b716cea11b5d'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 9, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 190.13382028229756,
#   'DrivingTime': 17570.0,
#   'TotalEnergy': 41.598876418416815,
#   'TotalStops': 10,
#   'TotalStopTime': 56830.0},
#  {'_id': ObjectId('631848b06861b716cea11b5e'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 10, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 432.81380811353546,
#   'DrivingTime': 23940.0,
#   'TotalEnergy': 98.15652341840317,
#   'TotalStops': 10,
#   'TotalStopTime': 49640.0},
#  {'_id': ObjectId('631848b46861b716cea11b5f'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 11, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 358.7680871322706,
#   'DrivingTime': 31520.0,
#   'TotalEnergy': 85.27875002908272,
#   'TotalStops': 7,
#   'TotalStopTime': 17500.0},
#  {'_id': ObjectId('631848b76861b716cea11b60'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 12, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 311.80498098631176,
#   'DrivingTime': 20450.0,
#   'TotalEnergy': 72.89791940514174,
#   'TotalStops': 8,
#   'TotalStopTime': 58730.0},
#  {'_id': ObjectId('631848bb6861b716cea11b61'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 13, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 249.28939817040958,
#   'DrivingTime': 19320.0,
#   'TotalEnergy': 54.985579816687604,
#   'TotalStops': 5,
#   'TotalStopTime': 60720.0},
#  {'_id': ObjectId('631848bf6861b716cea11b62'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 14, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 316.1730040955754,
#   'DrivingTime': 20090.0,
#   'TotalEnergy': 73.67601603893557,
#   'TotalStops': 11,
#   'TotalStopTime': 59930.0},
#  {'_id': ObjectId('631848c36861b716cea11b63'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 15, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 381.19980351574077,
#   'DrivingTime': 30060.0,
#   'TotalEnergy': 84.5776754648854,
#   'TotalStops': 9,
#   'TotalStopTime': 54860.0},
#  {'_id': ObjectId('631848c66861b716cea11b64'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 16, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 358.0058688380403,
#   'DrivingTime': 25930.0,
#   'TotalEnergy': 82.77211369305819,
#   'TotalStops': 9,
#   'TotalStopTime': 49400.0},
#  {'_id': ObjectId('631848cb6861b716cea11b65'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 17, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 449.30230990360843,
#   'DrivingTime': 29840.0,
#   'TotalEnergy': 101.71648287429265,
#   'TotalStops': 6,
#   'TotalStopTime': 41420.0},
#  {'_id': ObjectId('631848ce6861b716cea11b66'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 18, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 426.3296086127857,
#   'DrivingTime': 30150.0,
#   'TotalEnergy': 92.67373718036006,
#   'TotalStops': 7,
#   'TotalStopTime': 15960.0},
#  {'_id': ObjectId('631848d26861b716cea11b67'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 19, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 300.6809086138195,
#   'DrivingTime': 23660.0,
#   'TotalEnergy': 67.69125127030418,
#   'TotalStops': 10,
#   'TotalStopTime': 24200.0},
#  {'_id': ObjectId('631848d66861b716cea11b68'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 20, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 309.1709995599223,
#   'DrivingTime': 25360.0,
#   'TotalEnergy': 70.2912224094649,
#   'TotalStops': 10,
#   'TotalStopTime': 50670.0},
#  {'_id': ObjectId('631848da6861b716cea11b69'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 21, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 251.30414629806373,
#   'DrivingTime': 21780.0,
#   'TotalEnergy': 59.816968625551844,
#   'TotalStops': 8,
#   'TotalStopTime': 22660.0},
#  {'_id': ObjectId('631848dd6861b716cea11b6a'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 22, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 276.50885169332383,
#   'DrivingTime': 20070.0,
#   'TotalEnergy': 62.08547330952085,
#   'TotalStops': 8,
#   'TotalStopTime': 17940.0},
#  {'_id': ObjectId('631848e26861b716cea11b6b'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 23, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 338.8252240539768,
#   'DrivingTime': 21000.0,
#   'TotalEnergy': 75.00102581939804,
#   'TotalStops': 8,
#   'TotalStopTime': 58320.0},
#  {'_id': ObjectId('631848e56861b716cea11b6c'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 24, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 337.99298146794814,
#   'DrivingTime': 23240.0,
#   'TotalEnergy': 79.05638558098663,
#   'TotalStops': 8,
#   'TotalStopTime': 20790.0},
#  {'_id': ObjectId('631848e86861b716cea11b6d'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 25, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 364.4189694149749,
#   'DrivingTime': 28390.0,
#   'TotalEnergy': 81.87022820739391,
#   'TotalStops': 9,
#   'TotalStopTime': 21090.0},
#  {'_id': ObjectId('631848ec6861b716cea11b6e'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 26, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 270.79182211825673,
#   'DrivingTime': 23760.0,
#   'TotalEnergy': 62.92619512399796,
#   'TotalStops': 10,
#   'TotalStopTime': 20050.0},
#  {'_id': ObjectId('631848f06861b716cea11b6f'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 27, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 199.32297292093787,
#   'DrivingTime': 23450.0,
#   'TotalEnergy': 46.31664912031494,
#   'TotalStops': 6,
#   'TotalStopTime': 48390.0},
#  {'_id': ObjectId('631848f36861b716cea11b70'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 28, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 263.3331800079999,
#   'DrivingTime': 25890.0,
#   'TotalEnergy': 57.59071341775639,
#   'TotalStops': 6,
#   'TotalStopTime': 14730.0},
#  {'_id': ObjectId('631848f66861b716cea11b71'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 29, 0, 0),
#   'TotalTrips': 2,
#   'DistanceTravelled': 418.1788710508829,
#   'DrivingTime': 32620.0,
#   'TotalEnergy': 125.24949940989808,
#   'TotalStops': 3,
#   'TotalStopTime': 7890.0},
#  {'_id': ObjectId('631848fa6861b716cea11b72'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 30, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 388.3620288327401,
#   'DrivingTime': 31600.0,
#   'TotalEnergy': 88.4250656385328,
#   'TotalStops': 6,
#   'TotalStopTime': 51490.0},
#  {'_id': ObjectId('631848fe6861b716cea11b73'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 7, 31, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 462.056944647984,
#   'DrivingTime': 30160.0,
#   'TotalEnergy': 106.54222311962964,
#   'TotalStops': 8,
#   'TotalStopTime': 51590.0},
#  {'_id': ObjectId('631849026861b716cea11b74'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 8, 1, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 311.4372230336553,
#   'DrivingTime': 34300.0,
#   'TotalEnergy': 80.92126328889314,
#   'TotalStops': 7,
#   'TotalStopTime': 47200.0},
#  {'_id': ObjectId('631849066861b716cea11b75'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 8, 2, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 298.6275016023546,
#   'DrivingTime': 23420.0,
#   'TotalEnergy': 64.95540471448092,
#   'TotalStops': 10,
#   'TotalStopTime': 52110.0},
#  {'_id': ObjectId('6318490a6861b716cea11b76'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 8, 3, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 236.63227506019751,
#   'DrivingTime': 19470.0,
#   'TotalEnergy': 51.01738253801327,
#   'TotalStops': 9,
#   'TotalStopTime': 23870.0},
#  {'_id': ObjectId('6318490e6861b716cea11b77'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 8, 4, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 258.43866152731164,
#   'DrivingTime': 24280.0,
#   'TotalEnergy': 63.56313217918377,
#   'TotalStops': 9,
#   'TotalStopTime': 23630.0},
#  {'_id': ObjectId('631849126861b716cea11b78'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 8, 5, 0, 0),
#   'TotalTrips': 2,
#   'DistanceTravelled': 705.2997038541541,
#   'DrivingTime': 37070.0,
#   'TotalEnergy': 151.33152335602568,
#   'TotalStops': 4,
#   'TotalStopTime': 7750.0},
#  {'_id': ObjectId('631849176861b716cea11b79'),
#   'VehicleRegistration': 'KF44LNGP',
#   'Date': datetime.datetime(2022, 8, 8, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 196.8351199775211,
#   'DrivingTime': 18090.0,
#   'TotalEnergy': 48.51916866997924,
#   'TotalStops': 8,
#   'TotalStopTime': 24940.0},
#  {'_id': ObjectId('6318491b6861b716cea11b7a'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 1, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 396.3015067322481,
#   'DrivingTime': 25160.0,
#   'TotalEnergy': 91.36179814379557,
#   'TotalStops': 8,
#   'TotalStopTime': 25160.0},
#  {'_id': ObjectId('631849206861b716cea11b7b'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 3, 0, 0),
#   'TotalTrips': 2,
#   'DistanceTravelled': 58.2478125248637,
#   'DrivingTime': 5830.0,
#   'TotalEnergy': 11.95459005377737,
#   'TotalStops': 3,
#   'TotalStopTime': 5400.0},
#  {'_id': ObjectId('631849236861b716cea11b7c'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 4, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 430.9125952903698,
#   'DrivingTime': 26990.0,
#   'TotalEnergy': 95.70949950033351,
#   'TotalStops': 8,
#   'TotalStopTime': 20070.0},
#  {'_id': ObjectId('631849266861b716cea11b7d'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 5, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 225.7314955330199,
#   'DrivingTime': 17310.0,
#   'TotalEnergy': 55.041016358223345,
#   'TotalStops': 10,
#   'TotalStopTime': 25180.0},
#  {'_id': ObjectId('631849296861b716cea11b7e'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 6, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 322.02048160783016,
#   'DrivingTime': 24480.0,
#   'TotalEnergy': 70.49958503353388,
#   'TotalStops': 8,
#   'TotalStopTime': 28420.0},
#  {'_id': ObjectId('6318492b6861b716cea11b7f'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 7, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 407.8037183737617,
#   'DrivingTime': 28130.0,
#   'TotalEnergy': 82.35552760827403,
#   'TotalStops': 7,
#   'TotalStopTime': 19450.0},
#  {'_id': ObjectId('6318492e6861b716cea11b80'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 8, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 207.8415660188462,
#   'DrivingTime': 14860.0,
#   'TotalEnergy': 50.534169273553005,
#   'TotalStops': 8,
#   'TotalStopTime': 34090.0},
#  {'_id': ObjectId('631849316861b716cea11b81'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 9, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 382.3177618841599,
#   'DrivingTime': 25210.0,
#   'TotalEnergy': 94.96120484710934,
#   'TotalStops': 8,
#   'TotalStopTime': 30910.0},
#  {'_id': ObjectId('631849346861b716cea11b82'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 10, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 470.56807019872554,
#   'DrivingTime': 27970.0,
#   'TotalEnergy': 101.54216565289303,
#   'TotalStops': 5,
#   'TotalStopTime': 17190.0},
#  {'_id': ObjectId('631849386861b716cea11b83'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 11, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 270.6445354013613,
#   'DrivingTime': 22650.0,
#   'TotalEnergy': 61.524958132118634,
#   'TotalStops': 7,
#   'TotalStopTime': 26320.0},
#  {'_id': ObjectId('6318493b6861b716cea11b84'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 12, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 324.02009011567696,
#   'DrivingTime': 24470.0,
#   'TotalEnergy': 64.73640081422977,
#   'TotalStops': 11,
#   'TotalStopTime': 27070.0},
#  {'_id': ObjectId('6318493e6861b716cea11b85'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 13, 0, 0),
#   'TotalTrips': 8,
#   'DistanceTravelled': 350.2137366163793,
#   'DrivingTime': 27060.0,
#   'TotalEnergy': 85.66467625046914,
#   'TotalStops': 9,
#   'TotalStopTime': 23700.0},
#  {'_id': ObjectId('631849416861b716cea11b86'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 14, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 142.47873338685338,
#   'DrivingTime': 9980.0,
#   'TotalEnergy': 30.69132695832254,
#   'TotalStops': 7,
#   'TotalStopTime': 64870.0},
#  {'_id': ObjectId('631849446861b716cea11b87'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 15, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 443.67305079804976,
#   'DrivingTime': 34900.0,
#   'TotalEnergy': 96.72779023836856,
#   'TotalStops': 4,
#   'TotalStopTime': 12500.0},
#  {'_id': ObjectId('631849476861b716cea11b88'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 16, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 160.84171584436635,
#   'DrivingTime': 7710.0,
#   'TotalEnergy': 37.780032828742705,
#   'TotalStops': 7,
#   'TotalStopTime': 46150.0},
#  {'_id': ObjectId('6318494a6861b716cea11b89'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 17, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 190.83349815789236,
#   'DrivingTime': 14070.0,
#   'TotalEnergy': 49.53118503802198,
#   'TotalStops': 6,
#   'TotalStopTime': 23850.0},
#  {'_id': ObjectId('6318494e6861b716cea11b8a'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 18, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 337.98690156156056,
#   'DrivingTime': 23180.0,
#   'TotalEnergy': 79.06131258658098,
#   'TotalStops': 7,
#   'TotalStopTime': 17730.0},
#  {'_id': ObjectId('631849516861b716cea11b8b'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 19, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 290.6386737038092,
#   'DrivingTime': 16460.0,
#   'TotalEnergy': 64.11960521251845,
#   'TotalStops': 6,
#   'TotalStopTime': 11670.0},
#  {'_id': ObjectId('631849546861b716cea11b8c'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 20, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 401.8327902973426,
#   'DrivingTime': 30200.0,
#   'TotalEnergy': 87.08571261729925,
#   'TotalStops': 6,
#   'TotalStopTime': 13170.0},
#  {'_id': ObjectId('631849576861b716cea11b8d'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 21, 0, 0),
#   'TotalTrips': 9,
#   'DistanceTravelled': 401.2954187570342,
#   'DrivingTime': 32670.0,
#   'TotalEnergy': 86.96890549764484,
#   'TotalStops': 10,
#   'TotalStopTime': 21990.0},
#  {'_id': ObjectId('6318495a6861b716cea11b8e'),
#   'VehicleRegistration': 'KK65XRGP',
#   'Date': datetime.datetime(2022, 7, 22, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 315.15468777351373,
#   'DrivingTime': 25700.0,
#   'TotalEnergy': 69.33625780315839,
#   'TotalStops': 8,
#   'TotalStopTime': 22890.0},
#  {'_id': ObjectId('6318495e6861b716cea11b8f'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 1, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 271.11616456427373,
#   'DrivingTime': 23580.0,
#   'TotalEnergy': 71.01758681217875,
#   'TotalStops': 9,
#   'TotalStopTime': 23970.0},
#  {'_id': ObjectId('631849616861b716cea11b90'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 2, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 268.7467320790717,
#   'DrivingTime': 22150.0,
#   'TotalEnergy': 72.81099131975958,
#   'TotalStops': 9,
#   'TotalStopTime': 50300.0},
#  {'_id': ObjectId('631849636861b716cea11b91'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 3, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 227.7421134694426,
#   'DrivingTime': 15220.0,
#   'TotalEnergy': 58.11872296997413,
#   'TotalStops': 10,
#   'TotalStopTime': 21300.0},
#  {'_id': ObjectId('631849666861b716cea11b92'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 4, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 468.40377180935866,
#   'DrivingTime': 31790.0,
#   'TotalEnergy': 126.41251779399879,
#   'TotalStops': 7,
#   'TotalStopTime': 49350.0},
#  {'_id': ObjectId('631849696861b716cea11b93'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 5, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 227.6623245752795,
#   'DrivingTime': 21590.0,
#   'TotalEnergy': 59.87485814903945,
#   'TotalStops': 8,
#   'TotalStopTime': 57780.0},
#  {'_id': ObjectId('631849726861b716cea11b94'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 8, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 243.75053179389505,
#   'DrivingTime': 14430.0,
#   'TotalEnergy': 51.21795898892821,
#   'TotalStops': 8,
#   'TotalStopTime': 32220.0},
#  {'_id': ObjectId('631849756861b716cea11b95'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 9, 0, 0),
#   'TotalTrips': 9,
#   'DistanceTravelled': 298.1551978001115,
#   'DrivingTime': 27530.0,
#   'TotalEnergy': 73.32181048327436,
#   'TotalStops': 9,
#   'TotalStopTime': 57360.0},
#  {'_id': ObjectId('631849776861b716cea11b96'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 10, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 175.29544499683615,
#   'DrivingTime': 13110.0,
#   'TotalEnergy': 43.83344355488182,
#   'TotalStops': 12,
#   'TotalStopTime': 69000.0},
#  {'_id': ObjectId('6318497a6861b716cea11b97'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 11, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 210.102564251035,
#   'DrivingTime': 17570.0,
#   'TotalEnergy': 57.25014534663175,
#   'TotalStops': 14,
#   'TotalStopTime': 59820.0},
#  {'_id': ObjectId('6318497e6861b716cea11b98'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 12, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 373.55973883197413,
#   'DrivingTime': 27860.0,
#   'TotalEnergy': 86.73992486463335,
#   'TotalStops': 9,
#   'TotalStopTime': 41220.0},
#  {'_id': ObjectId('631849806861b716cea11b99'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 13, 0, 0),
#   'TotalTrips': 1,
#   'DistanceTravelled': 72.74130552019518,
#   'DrivingTime': 2940.0,
#   'TotalEnergy': 20.21547145257762,
#   'TotalStops': 2,
#   'TotalStopTime': 55290.0},
#  {'_id': ObjectId('631849836861b716cea11b9a'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 14, 0, 0),
#   'TotalTrips': 2,
#   'DistanceTravelled': 90.35670125866653,
#   'DrivingTime': 8120.0,
#   'TotalEnergy': 22.87693012449642,
#   'TotalStops': 6,
#   'TotalStopTime': 21410.0},
#  {'_id': ObjectId('631849866861b716cea11b9b'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 15, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 336.01365705094037,
#   'DrivingTime': 23530.0,
#   'TotalEnergy': 79.59295600405952,
#   'TotalStops': 8,
#   'TotalStopTime': 19160.0},
#  {'_id': ObjectId('631849896861b716cea11b9c'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 16, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 446.9385419749426,
#   'DrivingTime': 31880.0,
#   'TotalEnergy': 110.56538466455605,
#   'TotalStops': 7,
#   'TotalStopTime': 17010.0},
#  {'_id': ObjectId('6318498c6861b716cea11b9d'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 17, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 373.6866012427346,
#   'DrivingTime': 25710.0,
#   'TotalEnergy': 89.75483738913083,
#   'TotalStops': 9,
#   'TotalStopTime': 25750.0},
#  {'_id': ObjectId('6318498f6861b716cea11b9e'),
#   'VehicleRegistration': 'KN34FKGP',
#   'Date': datetime.datetime(2022, 8, 18, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 299.3872865358695,
#   'DrivingTime': 17430.0,
#   'TotalEnergy': 67.68635868384841,
#   'TotalStops': 10,
#   'TotalStopTime': 36310.0},
#  {'_id': ObjectId('631849926861b716cea11b9f'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 1, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 322.85744694113055,
#   'DrivingTime': 30080.0,
#   'TotalEnergy': 63.09030036947081,
#   'TotalStops': 9,
#   'TotalStopTime': 16800.0},
#  {'_id': ObjectId('631849956861b716cea11ba0'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 2, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 306.20344757579676,
#   'DrivingTime': 28500.0,
#   'TotalEnergy': 62.11707428676579,
#   'TotalStops': 9,
#   'TotalStopTime': 25390.0},
#  {'_id': ObjectId('631849986861b716cea11ba1'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 3, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 155.58198869532538,
#   'DrivingTime': 12520.0,
#   'TotalEnergy': 33.03053071851754,
#   'TotalStops': 6,
#   'TotalStopTime': 31570.0},
#  {'_id': ObjectId('6318499b6861b716cea11ba2'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 4, 0, 0),
#   'TotalTrips': 2,
#   'DistanceTravelled': 210.74115960009175,
#   'DrivingTime': 20480.0,
#   'TotalEnergy': 45.54764018374102,
#   'TotalStops': 2,
#   'TotalStopTime': 13870.0},
#  {'_id': ObjectId('6318499e6861b716cea11ba3'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 5, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 374.12946590527656,
#   'DrivingTime': 35180.0,
#   'TotalEnergy': 86.28658300089751,
#   'TotalStops': 8,
#   'TotalStopTime': 14570.0},
#  {'_id': ObjectId('631849a16861b716cea11ba4'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 6, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 243.20302961185618,
#   'DrivingTime': 17300.0,
#   'TotalEnergy': 45.37095500668576,
#   'TotalStops': 6,
#   'TotalStopTime': 29110.0},
#  {'_id': ObjectId('631849a36861b716cea11ba5'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 7, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 118.45234321587272,
#   'DrivingTime': 11370.0,
#   'TotalEnergy': 26.368715275103717,
#   'TotalStops': 3,
#   'TotalStopTime': 18650.0},
#  {'_id': ObjectId('631849a66861b716cea11ba6'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 8, 0, 0),
#   'TotalTrips': 1,
#   'DistanceTravelled': 32.961437115883285,
#   'DrivingTime': 2950.0,
#   'TotalEnergy': 5.987739003792276,
#   'TotalStops': 4,
#   'TotalStopTime': 34760.0},
#  {'_id': ObjectId('631849a96861b716cea11ba7'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 9, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 197.9674611250121,
#   'DrivingTime': 11620.0,
#   'TotalEnergy': 40.39755630321238,
#   'TotalStops': 7,
#   'TotalStopTime': 40670.0},
#  {'_id': ObjectId('631849ac6861b716cea11ba8'),
#   'VehicleRegistration': 'KR87GHGP',
#   'Date': datetime.datetime(2022, 8, 10, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 609.6914574452472,
#   'DrivingTime': 38350.0,
#   'TotalEnergy': 118.9935055879682,
#   'TotalStops': 3,
#   'TotalStopTime': 7600.0},
#  {'_id': ObjectId('631849b26861b716cea11ba9'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 1, 0, 0),
#   'TotalTrips': 9,
#   'DistanceTravelled': 295.9073419020231,
#   'DrivingTime': 27620.0,
#   'TotalEnergy': 65.93015495918668,
#   'TotalStops': 14,
#   'TotalStopTime': 37800.0},
#  {'_id': ObjectId('631849b46861b716cea11baa'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 2, 0, 0),
#   'TotalTrips': 8,
#   'DistanceTravelled': 398.0376856677538,
#   'DrivingTime': 30930.0,
#   'TotalEnergy': 83.15178423449797,
#   'TotalStops': 9,
#   'TotalStopTime': 20120.0},
#  {'_id': ObjectId('631849b76861b716cea11bab'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 3, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 261.5914096637762,
#   'DrivingTime': 25150.0,
#   'TotalEnergy': 63.137860112266935,
#   'TotalStops': 8,
#   'TotalStopTime': 21590.0},
#  {'_id': ObjectId('631849ba6861b716cea11bac'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 4, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 158.69171404949657,
#   'DrivingTime': 20140.0,
#   'TotalEnergy': 41.612749903227716,
#   'TotalStops': 9,
#   'TotalStopTime': 46080.0},
#  {'_id': ObjectId('631849bd6861b716cea11bad'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 5, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 389.8945706750701,
#   'DrivingTime': 29280.0,
#   'TotalEnergy': 116.70728727977927,
#   'TotalStops': 9,
#   'TotalStopTime': 24260.0},
#  {'_id': ObjectId('631849c06861b716cea11bae'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 6, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 228.24543848094584,
#   'DrivingTime': 15900.0,
#   'TotalEnergy': 49.85570669339717,
#   'TotalStops': 6,
#   'TotalStopTime': 21590.0},
#  {'_id': ObjectId('631849c26861b716cea11baf'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 7, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 364.6237412991829,
#   'DrivingTime': 22750.0,
#   'TotalEnergy': 91.28092950413455,
#   'TotalStops': 8,
#   'TotalStopTime': 20630.0},
#  {'_id': ObjectId('631849c56861b716cea11bb0'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 8, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 146.49534117970333,
#   'DrivingTime': 14040.0,
#   'TotalEnergy': 33.32038386553349,
#   'TotalStops': 6,
#   'TotalStopTime': 22240.0},
#  {'_id': ObjectId('631849c86861b716cea11bb1'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 9, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 421.2396013970539,
#   'DrivingTime': 27530.0,
#   'TotalEnergy': 103.36723396688578,
#   'TotalStops': 7,
#   'TotalStopTime': 22170.0},
#  {'_id': ObjectId('631849cb6861b716cea11bb2'),
#   'VehicleRegistration': 'KR01YWGP',
#   'Date': datetime.datetime(2022, 8, 10, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 316.8264816898374,
#   'DrivingTime': 24350.0,
#   'TotalEnergy': 75.56269380293227,
#   'TotalStops': 6,
#   'TotalStopTime': 29550.0},
#  {'_id': ObjectId('631849ce6861b716cea11bb3'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 1, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 387.9878334108664,
#   'DrivingTime': 30970.0,
#   'TotalEnergy': 73.59128025358963,
#   'TotalStops': 7,
#   'TotalStopTime': 18660.0},
#  {'_id': ObjectId('631849d26861b716cea11bb4'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 2, 0, 0),
#   'TotalTrips': 2,
#   'DistanceTravelled': 559.4050194446671,
#   'DrivingTime': 42260.0,
#   'TotalEnergy': 110.12505496304817,
#   'TotalStops': 2,
#   'TotalStopTime': 6600.0},
#  {'_id': ObjectId('631849d56861b716cea11bb5'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 3, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 320.53565215741935,
#   'DrivingTime': 27400.0,
#   'TotalEnergy': 64.75228633858733,
#   'TotalStops': 7,
#   'TotalStopTime': 20960.0},
#  {'_id': ObjectId('631849d86861b716cea11bb6'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 4, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 291.9418733593915,
#   'DrivingTime': 26890.0,
#   'TotalEnergy': 51.799262438024954,
#   'TotalStops': 4,
#   'TotalStopTime': 6960.0},
#  {'_id': ObjectId('631849dc6861b716cea11bb7'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 5, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 632.321465913413,
#   'DrivingTime': 33630.0,
#   'TotalEnergy': 118.43011700993902,
#   'TotalStops': 6,
#   'TotalStopTime': 44070.0},
#  {'_id': ObjectId('631849df6861b716cea11bb8'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 6, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 260.21957000337954,
#   'DrivingTime': 19910.0,
#   'TotalEnergy': 56.210232594139384,
#   'TotalStops': 4,
#   'TotalStopTime': 23760.0},
#  {'_id': ObjectId('631849e26861b716cea11bb9'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 7, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 244.26826357756556,
#   'DrivingTime': 17140.0,
#   'TotalEnergy': 48.25627129814403,
#   'TotalStops': 8,
#   'TotalStopTime': 16020.0},
#  {'_id': ObjectId('631849e56861b716cea11bba'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 8, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 245.69249024870686,
#   'DrivingTime': 14780.0,
#   'TotalEnergy': 48.69448140158181,
#   'TotalStops': 5,
#   'TotalStopTime': 45050.0},
#  {'_id': ObjectId('631849e86861b716cea11bbb'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 9, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 277.392356994186,
#   'DrivingTime': 20900.0,
#   'TotalEnergy': 53.69080168194384,
#   'TotalStops': 8,
#   'TotalStopTime': 29970.0},
#  {'_id': ObjectId('631849eb6861b716cea11bbc'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 10, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 116.89623045666248,
#   'DrivingTime': 11110.0,
#   'TotalEnergy': 22.8468979692575,
#   'TotalStops': 8,
#   'TotalStopTime': 36410.0},
#  {'_id': ObjectId('631849ee6861b716cea11bbd'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 11, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 310.93256149271633,
#   'DrivingTime': 24650.0,
#   'TotalEnergy': 65.43475787007378,
#   'TotalStops': 10,
#   'TotalStopTime': 25980.0},
#  {'_id': ObjectId('631849f16861b716cea11bbe'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 12, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 349.83217640166555,
#   'DrivingTime': 26350.0,
#   'TotalEnergy': 71.39936550257465,
#   'TotalStops': 9,
#   'TotalStopTime': 29780.0},
#  {'_id': ObjectId('631849f46861b716cea11bbf'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 13, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 228.84081404806182,
#   'DrivingTime': 16540.0,
#   'TotalEnergy': 44.48307342022133,
#   'TotalStops': 6,
#   'TotalStopTime': 15970.0},
#  {'_id': ObjectId('631849f96861b716cea11bc0'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 15, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 444.4162455271321,
#   'DrivingTime': 29360.0,
#   'TotalEnergy': 87.26357329729203,
#   'TotalStops': 7,
#   'TotalStopTime': 15410.0},
#  {'_id': ObjectId('631849fc6861b716cea11bc1'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 16, 0, 0),
#   'TotalTrips': 3,
#   'DistanceTravelled': 239.76250048083796,
#   'DrivingTime': 18310.0,
#   'TotalEnergy': 47.541704097059565,
#   'TotalStops': 4,
#   'TotalStopTime': 12680.0},
#  {'_id': ObjectId('631849ff6861b716cea11bc2'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 17, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 518.9248127092594,
#   'DrivingTime': 36920.0,
#   'TotalEnergy': 98.85170884331569,
#   'TotalStops': 7,
#   'TotalStopTime': 21860.0},
#  {'_id': ObjectId('63184a026861b716cea11bc3'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 18, 0, 0),
#   'TotalTrips': 7,
#   'DistanceTravelled': 541.4937193627812,
#   'DrivingTime': 36460.0,
#   'TotalEnergy': 105.19722027448802,
#   'TotalStops': 9,
#   'TotalStopTime': 19450.0},
#  {'_id': ObjectId('63184a056861b716cea11bc4'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 19, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 205.6848434979506,
#   'DrivingTime': 16040.0,
#   'TotalEnergy': 38.745067889690205,
#   'TotalStops': 7,
#   'TotalStopTime': 27020.0},
#  {'_id': ObjectId('63184a086861b716cea11bc5'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 20, 0, 0),
#   'TotalTrips': 6,
#   'DistanceTravelled': 521.8537547469551,
#   'DrivingTime': 29010.0,
#   'TotalEnergy': 109.56625426402688,
#   'TotalStops': 8,
#   'TotalStopTime': 23770.0},
#  {'_id': ObjectId('63184a0b6861b716cea11bc6'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 21, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 422.35578836036836,
#   'DrivingTime': 25840.0,
#   'TotalEnergy': 85.58885990873075,
#   'TotalStops': 9,
#   'TotalStopTime': 19460.0},
#  {'_id': ObjectId('63184a0e6861b716cea11bc7'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 22, 0, 0),
#   'TotalTrips': 5,
#   'DistanceTravelled': 340.8493659014025,
#   'DrivingTime': 28070.0,
#   'TotalEnergy': 63.094666673814224,
#   'TotalStops': 8,
#   'TotalStopTime': 25770.0},
#  {'_id': ObjectId('63184a106861b716cea11bc8'),
#   'VehicleRegistration': 'KK65WZGP',
#   'Date': datetime.datetime(2022, 8, 23, 0, 0),
#   'TotalTrips': 4,
#   'DistanceTravelled': 291.84633591607815,
#   'DrivingTime': 25430.0,
#   'TotalEnergy': 62.609244298309235,
#   'TotalStops': 6,
#   'TotalStopTime': 17600.0}]

# %%
carReg = [x['VehicleRegistration']for x in daysInfo]
date = [x['Date'] for x in daysInfo]
trips = [x['TotalTrips']for x in daysInfo]
distance = [x['DistanceTravelled'] for x in daysInfo]
driveTime = [x['DrivingTime']for x in daysInfo]
energy = [x['TotalEnergy']for x in daysInfo]
stops = [x['TotalStops'] for x in daysInfo]
stopTime = [x['TotalStopTime']for x in daysInfo]

# %%
start = start = [x['start'] for x in trip_details]
end = [x['end'] for x in trip_details]
energy = [x['energy'] for x in trip_details]
distance = [x['distance'] for x in trip_details]
duration = [x['duration'] for x in trip_details]
carReg = [x['VehicleRegistration']for x in trip_details]
epk = [EPK(x['energy'], x['distance']) for x in trip_details]
vave = [x['aveVelocity'] for x in trip_details]

# %%
d = {
    "Reg": carReg,
    "start":start,
    "end": end,
    "duration":duration,
    "distance":distance,
    "energy": energy,
    "epk": epk,
    "v ave": vave
    
}

# %%
df = pd.DataFrame(d)
df

# %%
df['duration'].div(60).round(2)

# %%
def min2(x,y):
    if x < y:
        return x
    else:
        return y

# %%
cars = ['KF44LNGP', 'KK65XRGP', 'KN34FKGP', 'KR87GHGP', 'KR01YWGP', 'KK65WZGP']
car_df = []
for car in cars:
    x = df[df['Reg'] == car]
    summary = x.describe()
    upq = summary['duration'].iloc[6]
    lq = summary['duration'].iloc[4]
    iqr = upq-lq
    max_iqr = iqr*1.5+upq
    max_quantile = x['duration'].quantile(0.95)
    max_thresh = min2(max_iqr, max_quantile)
    
    x=x[x['duration'] < max_thresh]
    
    summary = x.describe()
    upq = summary['distance'].iloc[6]
    lq = summary['distance'].iloc[4]
    iqr = upq-lq
    max_iqr = iqr*1.5+upq
    max_quantile = x['distance'].quantile(0.95)
    max_thresh = min2(max_iqr, max_quantile)
    
    min_quantile = x['distance'].quantile(0.025)
    
    x=x[(x['distance'] < max_thresh) & (x['distance'] > min_quantile)]
    car_df.append(x)

# %%
plt.rcParams["figure.figsize"] = [8, 4]
plt.rcParams["figure.autolayout"] = True
bps  = []
for c in car_df:
    bps.append(c.epk)
    
plt.boxplot(bps)
plt.ylabel("Energy Consumed (kwh/km)")
plt.xticks(np.arange(1,7), cars)
plt.title("Box and Whisker Plots for Energy Consumed (kwh/km) per trip")
plt.savefig("epk.png")

# %%
plt.rcParams["figure.figsize"] = [8, 4]
plt.rcParams["figure.autolayout"] = True
bps  = []
for c in car_df:
    c['duration'] = c['duration'].div(60).round(2)
    bps.append(c.duration)
    
plt.boxplot(bps)
plt.ylabel("Duration (mins)")
plt.xticks(np.arange(1,7), cars)
plt.title("Box and Whisker Plots for Trip Duration (minutes)")
plt.savefig('tripDur.png')

# %%
plt.rcParams["figure.figsize"] = [8, 4]
plt.rcParams["figure.autolayout"] = True
bps  = []
for c in car_df:
    bps.append(c.distance)
    
plt.boxplot(bps)
plt.ylabel("Distaqnce (km)")
plt.xticks(np.arange(1,7), cars)
plt.title("Box and Whisker Plots for Trip Distance (km)")
plt.savefig("tripdistance.png")

# %%
data_dir = 'D:\\Telematics\\Car Track\\Data\\DataStore'
file = os.path.join(data_dir, 'trip.csv')
df.to_csv(file, index=False)

# %%
df_trip = spark.read.csv(file, inferSchema=True, header=True)

# %%
df_trip.describe().show()

# %%
filter_df = df_trip.filter(df_trip.duration <= 12000).filter(df_trip.distance < 200)
filter_df.describe().show()

# %%
dur_df.describe()

# %%
stops = Stops.find()

stop_d = []
for stop in stops:
    stop_d.append(stop)

# %%
stop_d

# %%
start_s = [x['start'] for x in stop_d]
end_s = [x['end'] for x in stop_d]
latitude_s = [x['latitude'] for x in stop_d]
longitude_s = [x['longitude'] for x in stop_d]
duration_s = [x['duration'] for x in stop_d]
carReg_s = [x['VehicleRegistration']for x in stop_d]

# %%
d = {
    "registration":carReg_s,
    "start":start_s,
    "end": end_s,
    "latitude":latitude_s,
    "longitude":longitude_s,
    "duration": duration_s
}

df_stop = pd.DataFrame(d)
df_stop["start time"] = df_stop['start'].apply(lambda x: x.strftime('%H:%M:%S'))
df_stop = df_stop[df_stop['start time'].between('04:00:00', '21:00:00')]
df_stop['start time'] = df_stop['start time'].apply(lambda x : getTimeVal(x))
df_stop

# %%
cars = ['KF44LNGP', 'KK65XRGP', 'KN34FKGP', 'KR87GHGP', 'KR01YWGP', 'KK65WZGP']
car_df = []
for car in cars:
    x = df_stop[df_stop['registration'] == car]
    summary = x.describe()
    print()
    upq = summary['duration'].iloc[6]
    lq = summary['duration'].iloc[4]
    iqr = upq-lq
    max_iqr = iqr*1.5+upq
    max_quantile = x['duration'].quantile(0.95)
    max_thresh = np.min([max_iqr, max_quantile])
    x=x[x['duration'] < max_thresh]
    
    car_df.append(x)

# %%
plt.rcParams["figure.figsize"] = [8, 4]
plt.rcParams["figure.autolayout"] = True
bps  = []
for c in car_df:
    bps.append(c.duration/3600)
    
plt.boxplot(bps)
plt.ylabel("Stop Duration (hours)")
plt.xticks(np.arange(1,7), cars)
plt.title("Box and Whisker Plots for Stop Durations (hours)")
plt.savefig('stops.png')

# %%
for i,c in enumerate(car_df):
    plt.rcParams["figure.figsize"] = [8, 4]
    plt.rcParams["figure.autolayout"] = True
    c = c.sort_values(by=['start time'])
    
    mu = np.mean(c.duration/3600)
    #median = np.median(c.duration/3600)
    std = np.std(c.duration/3600)
    
    textstr = '\n'.join(("Duration",
    r'$\mu=%.2f$' % (mu, ),
    r'$\sigma=%.2f$' % (std, )))
    props = dict(boxstyle='round',  alpha=0.5)
    
    mu_time = np.mean(c['start time'])
    std_time = np.std(c['start time'])
    
    textstr2 = '\n'.join(("Arrival",
    r'$\mu=%.2f$' % (mu_time, ),
    r'$\sigma=%.2f$' % (std_time, )))
    props = dict(boxstyle='round',  alpha=0.5)
    print(mu_time, std_time)
    
    
    plt.scatter(c["start time"], c.duration/3600)
    plt.xticks(np.arange(4,22,2))
    plt.yticks(np.arange(0,3,0.5))
    plt.title(f'{cars[i]} Duration of Stops vs Arrival Time')
    plt.ylabel("Duration of Stop (hours)")
    plt.xlabel("Time of Arrival (Hour of Day)")
    
    plt.text(16.2, 2.8, textstr, fontsize=10,
        verticalalignment='top', bbox=props)
    plt.text(18.2, 2.8, textstr2, fontsize=10,
        verticalalignment='top', bbox=props)
    
    plt.ylim([0,3])
    plt.xlim([4,21])
    plt.show()
    #plt.savefig(f'{cars[i]}stop.png')

# %%
min_lat = df_stop['latitude'].quantile(0.01)
max_lat = df_stop['latitude'].quantile(0.99)
min_lng = df_stop['longitude'].quantile(0.01)
max_lng = df_stop['longitude'].quantile(0.99)

# %%
lat_df = df_stop[(df_stop['latitude'] > min_lat) & (df_stop['latitude'] < max_lat) & (df_stop['longitude'] > min_lng) & (df_stop['longitude'] < max_lng)]
lat_df

# %%
plt.plot(lat_df['longitude'], lat_df['latitude'], marker='.', linewidth=0, color="#128128")
plt.grid(which="major", color="#cccccc", alpha=0.45)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
dbscan_data = lat_df[['longitude', 'latitude']]
dbscan_data = dbscan_data.values.astype('float32', copy=False)
dbscan_data

# %%
dbscan_data_scaler = StandardScaler().fit(dbscan_data)
dbscan_data = dbscan_data_scaler.transform(dbscan_data)
dbscan_data

# %%
model = DBSCAN(eps=0.3, min_samples=12).fit(dbscan_data)
model

# %%
outliers_df = lat_df[model.labels_ == -1]
clusters_df = lat_df[model.labels_ != -1]

colors = model.labels_
colors_cluster = colors[colors != -1]
color_outlier = 'black'

clusters = Counter(model.labels_)
print(clusters)
print(lat_df[model.labels_ == -1].head())
print(f'No of Clusters = {len(clusters)-1}')

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
ax.scatter(clusters_df['longitude'], clusters_df['latitude'], c= colors_cluster, edgecolors="black", s=50)
#ax.scatter(outliers_df['longitude'], outliers_df['latitude'], c= color_outlier, edgecolors="black", s=50)
plt.title('Clustered GPS signals by DBSCAN algorithm', family='Arial', fontsize=12)
plt.grid(which="major", color="#cccccc", alpha=0.45)
plt.show()

# %%
fig = ex.scatter_mapbox(
clusters_df,
lat=clusters_df['latitude'],
lon=clusters_df['longitude'],
zoom = 10,
size_max=20, 
title="GeoTagging", 
width=1200, 
height =800, 
template="plotly_dark", 
)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
c['start time'].apply(lambda x : getTimeVal(x))

# %%
fig = px.histogram(x=duration_s,nbins=50)
fig.show()

# %%
df

# %%
data_dir = 'D:\\Telematics\\Car Track\\Data\\DataStore'
file = os.path.join(data_dir, 'trip.csv')
df.to_csv(file, index=False)

# %%
sparkdf = spark.read.csv(file, inferSchema=True, header=True)

# %%
sparkdf.printSchema()

# %%
sparkdf.describe().show()

# %%
sparkdf.filter(df.Reg == lit(cars[0])).show()

# %%
cars = [x.Reg for x in sparkdf.select('Reg').distinct().collect()]

# %%
for i,car in enumerate(cars):
    temp = sparkdf.filter(sparkdf.Reg == lit(car)).filter((sparkdf.duration >= 600)& (sparkdf.duration < 3600)).filter(sparkdf.distance <= 150)
    temp.describe().show()
    duration = [x.duration for x in temp.select('duration').collect()]
    distance = [x.distance for x in temp.select('distance').collect()]
    
    #plt.hist(duration, bins=200)
    fig = px.histogram(x=duration,nbins=50)
    fig.show()

# %%
plt.hist(distance, bins = 200)

# %%
time_df = sparkdf.withColumn("hour", hour(sparkdf.start)).withColumn("minute", minute(sparkdf.start)).withColumn("second", second(sparkdf.start))
time_df = time_df.sort(time_df.hour, time_df.minute, time_df.second).filter((time_df.hour >= 4) & (time_df.hour < 20))

# %%
time_df.show()

# %%
dur_x = [x.start.time() for x in time_df.select('start').collect()]
new_x = [datetime(2022,7,1,x.hour,x.minute,x.second).timestamp() for x in dur_x]

# %%
dur_y = [x.duration/3600 for x in time_df.select('duration').collect()]

# %%
reg = [x.CarRegistration for x in time_df.select("CarRegistration").collect()]

# %%
d = {
    "Time of Arrival":new_x,
    "Duration of stop events (Hours)": dur_y,
    "Car":reg
}

df = pd.DataFrame(d)
df

# %%
stop_stats = time_df.select('duration', 'hour').describe()
stop_stats.show()

# %%
df_val = df.iloc[:,[0,1]].values
df_val

# %%
plt.scatter(df_val[:,0], df_val[:,1], s=10, c="black")

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,
    init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(df_val)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.xlabel("Number of Clusters")
plt.show()

# %%
dbscan = DBSCAN(eps=0.0002, min_samples=20)

# %%
labels = dbscan.fit_predict(df_val)

# %%
labels

# %%
np.unique(labels)
